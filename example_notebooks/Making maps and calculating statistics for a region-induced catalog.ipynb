# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from utilities import plotting
from utilities import stats
from utilities import timestamps
from utilities import import_export
from utilities import polygon_selection
from mpl_toolkits.basemap import Basemap
from itertools import product
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing data

# %%
df = import_export.import_catalog(location='/home/max/pymap3/data/compact.csv'
                                 ,timestamp_column='none')

# %%
df.head()
# Out:
#                          mag       lat      lon  depth  x  y
# timestamp
# 2006-12-02 22:05:18.640  0.4  47.58561  7.59355   4289  0  0
# 2006-12-03 00:14:48.360  0.5  47.58561  7.59355   4295  0  0
# 2006-12-03 00:20:48.200  0.9  47.58709  7.59241   4199  0  0
# 2006-12-03 00:36:48.370  0.6  47.58593  7.59353   4518  0  0
# 2006-12-03 00:59:19.990  1.4  47.58637  7.59318   4343  0  0

# %%
df['depth'] = df['depth'] / 1e3

# %%
df.head()
# Out:
#                          mag       lat      lon  depth  x  y
# timestamp
# 2006-12-02 22:05:18.640  0.4  47.58561  7.59355  4.289  0  0
# 2006-12-03 00:14:48.360  0.5  47.58561  7.59355  4.295  0  0
# 2006-12-03 00:20:48.200  0.9  47.58709  7.59241  4.199  0  0
# 2006-12-03 00:36:48.370  0.6  47.58593  7.59353  4.518  0  0
# 2006-12-03 00:59:19.990  1.4  47.58637  7.59318  4.343  0  0

# %% [markdown]
# # Making plots for the region

# %%
fig, ax = plt.subplots(figsize=(10,5))
plotting.plot_seismicity_rate(dataframe=df, fig=fig, ax=ax)
#                               , lon_lat_min_max=[df.lon.min(), df.lon.max()
#                                                 ,df.lat.min(), df.lat.max()])
# Out:
# (<matplotlib.figure.Figure at 0x7f26520f1ba8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f26520fb2e8>)

# %%
plotting.plot_seismicity_map(dataframe=df, lon_lat_min_max=[df.lon.min(), df.lon.max()
                                                ,df.lat.min(), df.lat.max()])
# Out:
# (<mpl_toolkits.basemap.Basemap at 0x7f26524862b0>,
# ...
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f265213e358>)

# %%
fig, ax = plt.subplots()
plotting.plot_fmd_diagram(df, fig, ax)
# Out:
# /home/max/anaconda2/envs/research/lib/python3.5/site-packages/numpy/lib/function_base.py:747: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# /home/max/anaconda2/envs/research/lib/python3.5/site-packages/numpy/lib/function_base.py:748: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)
